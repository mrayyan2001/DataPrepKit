# %%
import DataPrepKit

# %%
df = DataPrepKit.read_data("summary.csv", "csv")

# %%
df.head()
# Out:
#        id                                               name  host_id  \
# 0   90676  Home in Columbus · ★4.82 · 3 bedrooms · 3 beds...   483306
# 1  543140  Home in Columbus · ★4.70 · 1 bedroom · 1 bed ·...  2350409
# 2  591101  Loft in Columbus · ★4.92 · 1 bedroom · 1 bed ·...  2889677
# 3  923248  Hostel in Columbus · ★4.74 · 1 bedroom · 5 bed...  4965048
# 4  927867  Hostel in Columbus · ★4.72 · 1 bedroom · 1 bed...  4965048
#
#        host_name  neighbourhood_group          neighbourhood  latitude  \
# 0  Audra & Lacey                  NaN  Near North/University  39.98366
# 1         Edward                  NaN  Near North/University  40.01114
# 2           Gail                  NaN              Near East  39.96041
# 3         Mathew                  NaN  Near North/University  40.01259
# 4         Mathew                  NaN  Near North/University  40.01259
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
DataPrepKit.summary(df)
# Out:
#                  id       host_id  neighbourhood_group     latitude  \
# count  2.668000e+03  2.668000e+03                  0.0  2668.000000
# mean   5.447430e+17  2.304476e+08                  NaN    39.983204
# std    4.116956e+17  1.747260e+08                  NaN     0.040084
# min    9.067600e+04  7.876100e+04                  NaN    39.870097
# 25%    4.983330e+07  6.782667e+07                  NaN    39.955740
# 50%    7.057537e+17  1.889271e+08                  NaN    39.977930
# 75%    9.002812e+17  4.264816e+08                  NaN    39.997612
# max    1.053696e+18  5.524346e+08                  NaN    40.147290
#
#          longitude        price  minimum_nights  number_of_reviews  \
# count  2668.000000  2579.000000      2668.00000        2668.000000
# mean    -82.989815   142.770066         7.45952          50.091454
# std       0.040977   124.446344        13.12943          85.014416
# min     -83.173610     9.000000         1.00000           0.000000
# ...

# %%
df = df.drop("neighbourhood_group", axis=1)

# %%
df.isna().sum()
# Out:
# id                                  0
# name                                0
# host_id                             0
# host_name                           0
# neighbourhood                       0
# latitude                            0
# longitude                           0
# room_type                           0
# price                              89
# minimum_nights                      0
# number_of_reviews                   0
# last_review                       381
# reviews_per_month                 381
# calculated_host_listings_count      0
# availability_365                    0
# number_of_reviews_ltm               0
# license                           368
# dtype: int64

# %%
DataPrepKit.handle_missing_values(df, "drop")

# %%
df.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# dtype: int64

# %%
df['room_type'] = DataPrepKit.encoding(df['room_type'])

# %%
df['room_type']
# Out:
# 0       0
# 1       1
# 2       1
# 3       2
# 4       1
#        ..
# 2612    1
# 2620    0
# 2631    0
# 2632    0
# 2638    0
# Name: room_type, Length: 2011, dtype: int64
